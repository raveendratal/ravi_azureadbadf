# %%
# create new data file using python dynamically.
def createFile(filename):
    f=open("/tmp/files/"+filename+".txt","w")
    for i in range(100000):
        f.write("sample data writting : "+str(i))
    f.close()
    print("File Created as : "+str(filename))
    return filename

# %%
# %fs ls file:/tmp/files/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>file:/tmp/files/sample85.txt</td><td>sample85.txt</td><td>2788890</td><td>1657299325169</td></tr><tr><td>file:/tmp/files/sample40.txt</td><td>sample40.txt</td><td>2788890</td><td>1657299322637</td></tr><tr><td>file:/tmp/files/sample3.txt</td><td>sample3.txt</td><td>2788890</td><td>1657299322157</td></tr><tr><td>file:/tmp/files/sample44.txt</td><td>sample44.txt</td><td>2788890</td><td>1657299322665</td></tr><tr><td>file:/tmp/files/sample57.txt</td><td>sample57.txt</td><td>2788890</td><td>1657299323181</td></tr><tr><td>file:/tmp/files/sample99.txt</td><td>sample99.txt</td><td>2788890</td><td>1657299326465</td></tr><tr><td>file:/tmp/files/sample29.txt</td><td>sample29.txt</td><td>2788890</td><td>1657299321053</td></tr><tr><td>file:/tmp/files/sample93.txt</td><td>sample93.txt</td><td>2788890</td><td>1657299325129</td></tr><tr><td>file:/tmp/files/sample14.txt</td><td>sample14.txt</td><td>2788890</td><td>1657299321625</td></tr><tr><td>file:/tmp/files/sample17.txt</td><td>sample17.txt</td><td>2788890</td><td>1657299321065</td></tr><tr><td>file:/tmp/files/sample81.txt</td><td>sample81.txt</td><td>2788890</td><td>1657299325181</td></tr><tr><td>file:/tmp/files/sample7.txt</td><td>sample7.txt</td><td>2788890</td><td>1657299322113</td></tr><tr><td>file:/tmp/files/sample87.txt</td><td>sample87.txt</td><td>2788890</td><td>1657299326185</td></tr><tr><td>file:/tmp/files/sample4.txt</td><td>sample4.txt</td><td>2788890</td><td>1657299320537</td></tr><tr><td>file:/tmp/files/sample30.txt</td><td>sample30.txt</td><td>2788890</td><td>1657299321641</td></tr><tr><td>file:/tmp/files/sample89.txt</td><td>sample89.txt</td><td>2788890</td><td>1657299325217</td></tr><tr><td>file:/tmp/files/sample66.txt</td><td>sample66.txt</td><td>2788890</td><td>1657299325589</td></tr><tr><td>file:/tmp/files/sample68.txt</td><td>sample68.txt</td><td>2788890</td><td>1657299324633</td></tr><tr><td>file:/tmp/files/sample53.txt</td><td>sample53.txt</td><td>2788890</td><td>1657299323197</td></tr><tr><td>file:/tmp/files/sample32.txt</td><td>sample32.txt</td><td>2788890</td><td>1657299322625</td></tr><tr><td>file:/tmp/files/sample61.txt</td><td>sample61.txt</td><td>2788890</td><td>1657299323177</td></tr><tr><td>file:/tmp/files/sample33.txt</td><td>sample33.txt</td><td>2788890</td><td>1657299323137</td></tr><tr><td>file:/tmp/files/sample41.txt</td><td>sample41.txt</td><td>2788890</td><td>1657299323133</td></tr><tr><td>file:/tmp/files/sample76.txt</td><td>sample76.txt</td><td>2788890</td><td>1657299324653</td></tr><tr><td>file:/tmp/files/sample2.txt</td><td>sample2.txt</td><td>2788890</td><td>1657299321597</td></tr><tr><td>file:/tmp/files/sample88.txt</td><td>sample88.txt</td><td>2788890</td><td>1657299324705</td></tr><tr><td>file:/tmp/files/sample0.txt</td><td>sample0.txt</td><td>2788890</td><td>1657299320541</td></tr><tr><td>file:/tmp/files/sample59.txt</td><td>sample59.txt</td><td>2788890</td><td>1657299324205</td></tr><tr><td>file:/tmp/files/sample35.txt</td><td>sample35.txt</td><td>2788890</td><td>1657299324165</td></tr><tr><td>file:/tmp/files/sample49.txt</td><td>sample49.txt</td><td>2788890</td><td>1657299323133</td></tr><tr><td>file:/tmp/files/sample78.txt</td><td>sample78.txt</td><td>2788890</td><td>1657299325665</td></tr><tr><td>file:/tmp/files/sample77.txt</td><td>sample77.txt</td><td>2788890</td><td>1657299325153</td></tr><tr><td>file:/tmp/files/sample13.txt</td><td>sample13.txt</td><td>2788890</td><td>1657299321041</td></tr><tr><td>file:/tmp/files/sample47.txt</td><td>sample47.txt</td><td>2788890</td><td>1657299324137</td></tr><tr><td>file:/tmp/files/sample75.txt</td><td>sample75.txt</td><td>2788890</td><td>1657299326169</td></tr><tr><td>file:/tmp/files/sample9.txt</td><td>sample9.txt</td><td>2788890</td><td>1657299321049</td></tr><tr><td>file:/tmp/files/sample91. ...

# %%
createFile("sample")
# Out:
# File Created as : sample
# Out[2]: 'sample'

# %% [markdown]
# #### Python multiprocessing
#
# * multiprocessing is a package that supports spawning processes using an API similar to the threading module. The multiprocessing package offers both local and remote concurrency, effectively side-stepping the Global Interpreter Lock by using subprocesses instead of threads. Due to this, the multiprocessing module allows the programmer to fully leverage multiple processors on a given machine. It runs on both Unix and Windows.

# %%
from multiprocessing.pool import ThreadPool
parallels = ThreadPool(8)
parallels.map(createFile,[ "sample"+str(i) for i in range(100)])
# Out:
# File Created as : sample12
# File Created as : sample4
# File Created as : sample0
# File Created as : sample24
# File Created as : sample28
# File Created as : sample8
# File Created as : sample16
# File Created as : sample20
# File Created as : sample25
# File Created as : sample13
# File Created as : sample5
# File Created as : sample1
# File Created as : sample9
# File Created as : sample29
# File Created as : sample17
# File Created as : sample21
# File Created as : sample2
# File Created as : sample6
# File Created as : sample10
# File Created as : sample26
# File Created as : sample14
# File Created as : sample18
# File Created as : sample30
# File Created as : sample22
# File Created as : sample7
# File Created as : sample27
# File Created as : sample15
# File Created as : sample3
# File Created as : sample31
# File Created as : sample19
# File Created as : sample11
# File Created as : sample23
# File Created as : sample32
# File Created as : sample36
# File Created as : sample40
# File Created as : sample48
# File Created as : sample44
# File Created as : sample60
# File Created as : sample56
# File Created as : sample52
# File Created as : sample41File Created as : sample49
#
# File Created as : sample33
# File Created as : sample37
# File Created as : sample45
# File Created as : sample61
# File Created as : sample57
# File Created as : sample53
# File Created as : sample50
# File Created as : sample42
# File Created as : sample46
# File Created as : sample34
# File Created as : sample38
# File Created as : sample62
# File Created as : sample58
# File Created as : sample54
# File Created as : sample51
# File Created as : sample47
# File Created as : sample43
# File Created as : sample39
# File Created as : sample35
# File Created as : sample63
# File Created as : sample55
# File Created as : sample59
# File Created as : sample64
# File Created as : sample68
# File Created as : sample72
# File Created as : sample76
# File Created as : sample80
# File Created as : sample92
# File Created as : sample84
# File Created as : sample88
# File Created as : sample65
# File Created as : sample93
# File Created as : sample69
# File Created as : sample77
# File Created as : sample73
# File Created as : sample85
# File Created as : sample81
# File Created as : sample89
# File Created as : sample66
# File Created as : sample94
# File Created as : sample78
# File Created as : sample70
# File Created as : sample74
# File Created as : sample86
# File Created as : sample82
# File Created as : sample90
# File Created as : sample67
# File Created as : sample75
# File Created as : sample79
# File Created as : sample95
# File Created as : sample71
# File Created as : sample87
# File Created as : sample83
# File Created as : sample91
# File Created as : sample96
# File Created as : sample97
# File Created as : sample98
# File Created as : sample99
# Out[3]: ['sample0',
#  'sample1',
#  'sample2',
#  'sample3',
#  'sample4',
#  'sample5',
#  'sample6',
#  'sample7',
#  'sample8',
#  'sample9',
#  'sample10',
#  'sample11',
#  'sample12',
#  'sample13',
#  'sample14',
#  'sample15',
#  'sample16',
#  'sample17',
#  'sample18',
#  'sample19',
#  'sample20',
#  'sample21',
#  'sample22',
#  'sample23',
#  'sample24',
#  'sample25',
#  'sample26',
#  'sample27',
#  'sample28',
#  'sample29',
#  'sample30',
#  'sample31',
#  'sample32',
#  'sample33',
#  'sample34',
#  'sample35',
#  'sample36',
#  'sample37',
#  'sample38',
#  'sample39',
#  'sample40',
#  'sample41',
#  'sample42',
#  'sample43',
#  'sample44',
#  'sample45',
#  'sample46',
#  'sample47',
#  'sample48',
#  'sample49',
#  'sample50',
#  'sample51',
#  'sample52',
#  'sample53',
#  'sample54',
#  'sample55',
#  'sample56',
#  'sample57',
#  'sample58',
#  'sample59',
#  'sample60',
#  'sample61',
#  'sample62',
#  'sample63',
#  'sample64',
#  'sample65',
#  'sample66',
#  'sample67',
#  'sample68',
#  'sample69',
#  'sample70',
#  'sample71',
#  'sample72',
#  'sample73',
#  'sample74',
#  'sample75',
#  'sample76',
#  'sample77',
#  'sample78',
#  'sample79',
#  'sample80',
#  'sample81',
#  'sample82',
#  'sample83',
#  'sample84',
#  'sample85',
#  'sample86',
#  'sample87',
#  'sample88',
#  'sample89',
#  'sample90',
#  'sample91',
#  'sample92',
#  'sample93',
#  'sample94',
#  'sample95',
#  'sample96',
#  'sample97',
#  'sample98',
#  'sample99']
